# %%
import pandas as pd
# Try manually:
df = pd.read_csv('test_csv.csv')
print("Success with latin1!")
# Out:
# Success with latin1!

# %%
df
# Out:
#       NCT Number                           Primary Outcome Measures  \
# 0    NCT00072579        Cytogenetic response (complete and partial)
# 1    NCT01402479         headache frequency, headache days, 12 week
# 2    NCT00812279  To demonstrate a reduction in the three primar...
# 3    NCT01511679                                                NaN
# 4    NCT05602779  Changes from Baseline to Follow-up Assessments...
# ..           ...                                                ...
# 929  NCT01615679      Clinical Global Impression (CGI), 12-14 weeks
# 930  NCT05572879  The proportion of GMT of neutralizing antibody...
# 931  NCT03395379  Failure rate of the air dissection procedure, ...
# 932  NCT01717079  BSQ-34 scale (Body Shape Questionnaire), Just ...
# 933  NCT02879279  Change from Baseline Fugl-Meyer Assessment of ...
#
#                             Secondary Outcome Measures Other Outcome Measures
# 0    Toxicity as assessed by the Expanded Common To...                    NaN
# 1                                                  NaN                    NaN
# 2    To explore changes from baseline COHb, S-PMA, ...                    NaN
# 3                                                  NaN                    NaN
# 4    Change from Baseline to Follow-up Assessments ...                    NaN
# ..                                                 ...                    ...
# 929  Wender-Reimherr adult attention deficit disord...                    NaN
# 930  Occurrence of solicited Adverse Events (AEs), ...                    NaN
# 931  Post-operative complications, Minor and major ...                    NaN
# 932  EAT-40 scale (eating attitude test), Before rT...                    NaN
# 933  Change from Baseline Motricity Index, It is a ...                    NaN
#
# [934 rows x 4 columns]

# %%
# Convert CSV to UTF-8 first in Python:
import pandas as pd
df = pd.read_csv('test_csv.csv')
df.to_csv('test_csv_clean.csv', encoding='utf-8', index=False)

# %%
# test_csv_direct.py
import pandas as pd
import sys
import os
sys.path.append('src')

from src.csv_utils.csv_processor import CSVProcessor

# Test direct processing
processor = CSVProcessor()
success = processor.process_csv_file(
    csv_file_path="test_csv_clean.csv",
    model_id="test_direct",
    batch_size=50
)
print(f"Success: {success}")
# Out:
# Success: True

# %%
df= pd.read_csv('studiesAndEndpoints.csv')

# %%
df
# Out:
#          NCT Number                           Primary Outcome Measures  \
# 0       NCT00072579        Cytogenetic response (complete and partial)
# 1       NCT01402479         headache frequency, headache days, 12 week
# 2       NCT00812279  To demonstrate a reduction in the three primar...
# 3       NCT01511679                                                NaN
# 4       NCT05602779  Changes from Baseline to Follow-up Assessments...
# ...             ...                                                ...
# 548267  NCT03261687  Pelvic Girdle Pain Questionnaire (PGPQ), A sco...
# 548268  NCT04122287  Eradication rates in 2 groups, Both intention ...
# 548269  NCT02254187  AUC0-∞ (area under the concentration-time curv...
# 548270  NCT02098187  Total plasma clearance of MP-3180 and iohexol,...
# 548271  NCT04475887  Hemoglobin at OLT, Change in hemoglobin concen...
#
#                                Secondary Outcome Measures  \
# 0       Toxicity as assessed by the Expanded Common To...
# 1                                                     NaN
# 2       To explore changes from baseline COHb, S-PMA, ...
# 3                                                     NaN
# 4       Change from Baseline to Follow-up Assessments ...
# ...                                                   ...
# 548267  Visual Analogue Scale (VAS), score change of 1...
# 548268  The rate of improving dyspepsia symptoms after...
# 548269  AUC0-tz (area under the concentration-time cur...
# 548270  Incidence of adverse events, An adverse event ...
# 548271  Transfusion requirement, Transfusion of PRBCs ...
#
#                                    Other Outcome Measures
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 548267                                                NaN
# 548268                                                NaN
# 548269                                                NaN
# 548270  Correlation between MP-3180 fluorescence inten...
# 548271                                                NaN
#
# [548272 rows x 4 columns]

# %%
df_sample = df.sample(frac=0.07)
df_sample
# Out:
#          NCT Number                           Primary Outcome Measures  \
# 155853  NCT06365216  The effect of NX210c on blood neurofilament li...
# 254324  NCT00990145  The study objective was to determine the safet...
# 128675  NCT02269748  Patient morbidity, Quantity of analgesics take...
# 134812  NCT00545922  Beck Anxiety Inventory, Intervention period of...
# 24446   NCT00324038  Average Daily Pain Scores - BS11 Pain Scores.,...
# ...             ...                                                ...
# 446381  NCT06326918  Specific microbial genus using mucosal brushin...
# 401779  NCT04648748  Hand Grip Strength, Hand grip strength can be ...
# 307208  NCT06812650  Gastroesophageal Reflux Disease Questionnaire,...
# 476619  NCT04839952  Change in Nutrition knowledge as assessed by t...
# 209204  NCT01822015  Change in measurement of mTOR activation paire...
#
#                                Secondary Outcome Measures  \
# 155853                                                NaN
# 254324                                                NaN
# 128675  Clinical measurements GH, Gingival recession h...
# 134812  St. George's Respiratory Questionnaire, Interv...
# 24446                                                 NaN
# ...                                                   ...
# 446381  Specific microbial genus using mucosal biopsy,...
# 401779                                                NaN
# 307208  The Hospital Anxiety and Depression Scale, The...
# 476619  Change in Healthy lifestyle self-efficacy as a...
# 209204  Overall survival, Will be evaluated using the ...
#
#        Other Outcome Measures
# 155853                    NaN
# 254324                    NaN
# 128675                    NaN
# 134812                    NaN
# 24446                     NaN
# ...                       ...
# 446381                    NaN
# 401779                    NaN
# 307208                    NaN
# 476619                    NaN
# 209204                    NaN
#
# [38379 rows x 4 columns]

# %%
df_sample.to_csv('sample_data_seven_percent.csv', index=False)
